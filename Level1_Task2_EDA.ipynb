# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Cleaned_Sentiment_Dataset.csv")

# %%
df.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#           Timestamp            User     Platform  \
# 0  15/01/2023 12:30   User123          Twitter
# 1  15/01/2023 08:45   CommuterX        Twitter
# 2  15/01/2023 15:45   FitnessFan      Instagram
# 3  15/01/2023 18:20   AdventureX       Facebook
# 4  15/01/2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                    15     30     USA
# 1   #Traffic #Morning                                 5     10     Canada
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       732 non-null    str
#  1   Sentiment  732 non-null    str
#  2   Timestamp  732 non-null    str
#  3   User       732 non-null    str
#  4   Platform   732 non-null    str
#  5   Hashtags   732 non-null    str
#  6   Retweets   732 non-null    int64
#  7   Likes      732 non-null    int64
#  8   Country    732 non-null    str
#  9   Year       732 non-null    int64
#  10  Month      732 non-null    int64
#  11  Day        732 non-null    int64
#  12  Hour       732 non-null    int64
# dtypes: int64(6), str(7)
# memory usage: 74.5 KB

# %%
df.describe()
# Out:
#          Retweets       Likes         Year       Month         Day        Hour
# count  732.000000  732.000000   732.000000  732.000000  732.000000  732.000000
# mean    21.508197   42.901639  2020.471311    6.122951   15.497268   15.521858
# std      7.061286   14.089848     2.802285    3.411763    8.474553    4.113414
# min      5.000000   10.000000  2010.000000    1.000000    1.000000    0.000000
# 25%     17.750000   34.750000  2019.000000    3.000000    9.000000   13.000000
# 50%     22.000000   43.000000  2021.000000    6.000000   15.000000   16.000000
# 75%     25.000000   50.000000  2023.000000    9.000000   22.000000   19.000000
# max     40.000000   80.000000  2023.000000   12.000000   31.000000   23.000000

# %%
df.mean(numeric_only=True)
# Out:
# Retweets      21.508197
# Likes         42.901639
# Year        2020.471311
# Month          6.122951
# Day           15.497268
# Hour          15.521858
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Retweets      22.0
# Likes         43.0
# Year        2021.0
# Month          6.0
# Day           15.0
# Hour          16.0
# dtype: float64

# %%
df.mode()
# Out:
#                                                 Text    Sentiment  \
# 0   A compassionate rain, tears of empathy fallin...   Positive
# 1   A playful escapade in the carnival of life, c...          NaN
# 2   Embraced by the hopeful dawn, a gardener sowi...          NaN
# 3   Proudly scaling the peaks of achievement, a m...          NaN
# 4                                                NaN          NaN
# 5                                                NaN          NaN
#
#           Timestamp               User     Platform  \
# 0  01/07/2021 12:10   CarnivalDreamer    Instagram
# 1  05/01/2020 08:45      DawnGardener           NaN
# 2  05/04/2019 17:30     PeakConqueror           NaN
# 3  17/07/2022 06:15      RainNurturer           NaN
# 4  22/08/2018 17:20     WindWhisperer           NaN
# 5               NaN   WinterWarmth              NaN
#
#                            Hashtags  Retweets  Likes Country    Year  Month  \
# ...

# %%
df.std(numeric_only=True)
# Out:
# Retweets     7.061286
# Likes       14.089848
# Year         2.802285
# Month        3.411763
# Day          8.474553
# Hour         4.113414
# dtype: float64

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Likes"], bins=20)
plt.title("Distribution of Likes")
plt.xlabel("Likes")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df["Likes"])
plt.title("Boxplot of Likes")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["Likes"], df["Retweets"])
plt.xlabel("Likes")
plt.ylabel("Retweets")
plt.title("Likes vs Retweets")
plt.show()

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#           Retweets     Likes      Year     Month       Day      Hour
# Retweets  1.000000  0.998482 -0.039982  0.073265  0.009213  0.196955
# Likes     0.998482  1.000000 -0.043415  0.066643  0.011489  0.195331
# Year     -0.039982 -0.043415  1.000000 -0.314845  0.021973 -0.087470
# Month     0.073265  0.066643 -0.314845  1.000000 -0.135873  0.137835
# Day       0.009213  0.011489  0.021973 -0.135873  1.000000  0.044072
# Hour      0.196955  0.195331 -0.087470  0.137835  0.044072  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# The exploratory data analysis (EDA) was successfully completed. Summary statistics (mean, median, mode, and standard deviation) were calculated. Data distributions were visualized using histograms, boxplots, and scatter plots. A correlation heatmap was generated to identify relationships among numerical variables. These analyses provide useful insights into the dataset and prepare it for further analysis.
